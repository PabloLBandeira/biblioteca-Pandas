# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloLBandeira/biblioteca-Pandas/blob/main/exerc%C3%ADcio_regress%C3%A3o_linear_multipla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.formula.api as smf

# %%
limite = pd.read_excel('/content/limite de credito.xlsx')
limite.head()
# Out:
#    Idade  RendimentoTotal  Salario  LimitedeCreditoImediato  \
# 0     70            10736     5214                      400
# 1     68             5000     5000                      380
# 2     44             5800     5800                      500
# 3     72             4300     4300                     2000
# 4     75             4400     4400                     3000
#
#         Escolaridade Gênero Região  LimitedoChequeEspecial
# 0  Fundamental_Medio     RJ      F                     500
# 1  Fundamental_Medio     RJ      F                     600
# 2  Fundamental_Medio     RJ      F                     800
# 3  Fundamental_Medio     RJ      F                    1000
# 4  Fundamental_Medio     RJ      F                    1000

# %%
limite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Idade                    48 non-null     int64
#  1   RendimentoTotal          48 non-null     int64
#  2   Salario                  48 non-null     int64
#  3   LimitedeCreditoImediato  48 non-null     int64
#  4   Escolaridade             48 non-null     object
#  5   Gênero                   48 non-null     object
#  6   Região                   48 non-null     object
#  7   LimitedoChequeEspecial   48 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 3.1+ KB

# %%
limite = pd.get_dummies(data=limite, columns=['Escolaridade', 'Gênero', 'Região'], prefix=['Escolaridade', 'Região', 'Gênero'])
limite.head()
# Out:
#    Idade  RendimentoTotal  Salario  LimitedeCreditoImediato  \
# 0     70            10736     5214                      400
# 1     68             5000     5000                      380
# 2     44             5800     5800                      500
# 3     72             4300     4300                     2000
# 4     75             4400     4400                     3000
#
#    LimitedoChequeEspecial  Escolaridade_Fundamental_Medio  \
# 0                     500                            True
# 1                     600                            True
# 2                     800                            True
# 3                    1000                            True
# 4                    1000                            True
#
#    Escolaridade_Superior_Pos  Região_RJ  Região_SP  Gênero_F  Gênero_M
# 0                      False       True      False      True     False
# 1                      False       True      False      True     False
# ...

# %%
limite.corr()
# Out:
#                                    Idade  RendimentoTotal   Salario  \
# Idade                           1.000000         0.239445  0.213186
# RendimentoTotal                 0.239445         1.000000  0.960551
# Salario                         0.213186         0.960551  1.000000
# LimitedeCreditoImediato         0.057183         0.031041  0.081792
# LimitedoChequeEspecial          0.228117         0.858120  0.888839
# Escolaridade_Fundamental_Medio -0.150088        -0.396191 -0.475479
# Escolaridade_Superior_Pos       0.150088         0.396191  0.475479
# Região_RJ                      -0.196052        -0.177798 -0.242621
# Região_SP                       0.196052         0.177798  0.242621
# Gênero_F                       -0.121217        -0.406241 -0.424335
# Gênero_M                        0.121217         0.406241  0.424335
#
#                                 LimitedeCreditoImediato  \
# Idade                                          0.057183
# ...

# %%
function = 'LimitedoChequeEspecial~Idade+RendimentoTotal+Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio+Escolaridade_Superior_Pos+Região_RJ+Região_SP+Gênero_F+Gênero_M'
model = smf.ols(formula=function, data=limite).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.886
# Model:                                OLS   Adj. R-squared:                  0.865
# Method:                     Least Squares   F-statistic:                     44.20
# Date:                    Thu, 27 Jun 2024   Prob (F-statistic):           7.44e-17
# Time:                            23:51:13   Log-Likelihood:                -434.21
# No. Observations:                      48   AIC:                             884.4
# Df Residuals:                          40   BIC:                             899.4
# Df Model:                               7
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
function = 'LimitedoChequeEspecial~RendimentoTotal+Salario+LimitedeCreditoImediato+Escolaridade_Fundamental_Medio+Escolaridade_Superior_Pos+Região_RJ+Região_SP+Gênero_F+Gênero_M'
model = smf.ols(formula=function, data=limite).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.885
# Model:                                OLS   Adj. R-squared:                  0.869
# Method:                     Least Squares   F-statistic:                     52.78
# Date:                    Thu, 27 Jun 2024   Prob (F-statistic):           9.97e-18
# Time:                            23:52:01   Log-Likelihood:                -434.24
# No. Observations:                      48   AIC:                             882.5
# Df Residuals:                          41   BIC:                             895.6
# Df Model:                               6
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
function = 'LimitedoChequeEspecial~RendimentoTotal+Salario+Escolaridade_Fundamental_Medio+Escolaridade_Superior_Pos+Região_RJ+Região_SP+Gênero_F+Gênero_M'
model = smf.ols(formula=function, data=limite).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.884
# Model:                                OLS   Adj. R-squared:                  0.871
# Method:                     Least Squares   F-statistic:                     64.26
# Date:                    Thu, 27 Jun 2024   Prob (F-statistic):           1.39e-18
# Time:                            23:52:21   Log-Likelihood:                -434.44
# No. Observations:                      48   AIC:                             880.9
# Df Residuals:                          42   BIC:                             892.1
# Df Model:                               5
# Covariance Type:                nonrobust
# ...
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
function = 'LimitedoChequeEspecial~RendimentoTotal+Salario+Escolaridade_Superior_Pos+Região_RJ+Região_SP+Gênero_F+Gênero_M'
model = smf.ols(formula=function, data=limite).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.884
# Model:                                OLS   Adj. R-squared:                  0.871
# Method:                     Least Squares   F-statistic:                     64.26
# Date:                    Thu, 27 Jun 2024   Prob (F-statistic):           1.39e-18
# Time:                            23:52:44   Log-Likelihood:                -434.44
# No. Observations:                      48   AIC:                             880.9
# Df Residuals:                          42   BIC:                             892.1
# Df Model:                               5
# Covariance Type:                nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %%
function = 'LimitedoChequeEspecial~RendimentoTotal+Salario++Região_RJ+Região_SP+Gênero_F+Gênero_M - 1'
model = smf.ols(formula=function, data=limite).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               OLS Regression Results
# ...
# Dep. Variable:     LimitedoChequeEspecial   R-squared:                       0.883
# Model:                                OLS   Adj. R-squared:                  0.872
# Method:                     Least Squares   F-statistic:                     80.75
# Date:                    Thu, 27 Jun 2024   Prob (F-statistic):           2.02e-19
# Time:                            23:53:30   Log-Likelihood:                -434.83
# No. Observations:                      48   AIC:                             879.7
# Df Residuals:                          43   BIC:                             889.0
# Df Model:                               4
# Covariance Type:                nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...
